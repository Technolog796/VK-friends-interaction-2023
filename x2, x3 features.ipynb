# %%
import numpy as np
import pandas as pd
from tqdm.auto import tqdm

# %%
class DiGraph:
    def __init__(self) -> None:
        self.max_v = -1
        self.edges = []

    def add_edge(self, u: int, v: int, x: float) -> None:
        self.max_v = max(self.max_v, max(u, v))
        self.edges.append((u, v, x))
        
    def get_n(self) -> int:
        return self.max_v + 1

    def get_m(self) -> int:
        return len(self.edges)

    def to_array(self) -> np.array:
        g = np.zeros((self.max_v + 1, self.max_v + 1), np.float32)
        for edge in self.edges:
            g[edge[0]][edge[1]] = 1 + edge[2]
        return g

# %%
def read_ego_net(ego_net_path):
    cur_ego_id = -1
    cur_ego_net_x2 = None
    cur_ego_net_x3 = None
    with open(ego_net_path, 'r') as ego_net_f:
        ego_net_f.readline()
        for line in ego_net_f:
            line = line.split(',')
            ego_id, u, v = int(line[0]), int(line[1]), int(line[2])
            x2, x3 = float(line[5]), float(line[6])

            if ego_id != cur_ego_id:
                if cur_ego_id != -1:
                    yield cur_ego_id, cur_ego_net_x2, cur_ego_net_x3
                assert cur_ego_id < ego_id
                cur_ego_id = ego_id
                cur_ego_net_x2 = DiGraph()
                cur_ego_net_x3 = DiGraph()
            
            cur_ego_net_x2.add_edge(u, v, x2)
            cur_ego_net_x3.add_edge(u, v, x3)

        if cur_ego_id != -1:
            yield cur_ego_id, cur_ego_net_x2, cur_ego_net_x3

# %%
train = pd.read_csv('./data/train.csv', index_col='ego_id', usecols=['ego_id', 'u', 'v', 'x1'])
train
# Out:
#                  u    v            x1
# ego_id
# 0              131   84  5.669200e-07
# 0              135  164  6.246274e-02
# 0               47   15  0.000000e+00
# 0                5    4  4.962974e-02
# 0              176  219  1.237935e+00
# ...            ...  ...           ...
# 1709396984692    3    5  2.307750e+00
# 1709396984692    1    5  3.729143e+00
# 1709396984692    1    7  4.286984e+00
# 1709396984692    5   11  3.500757e+00
# 1709396984692    3    1  5.773366e-02
#
# [122280372 rows x 3 columns]

# %%
test = pd.read_csv('./data/test.csv', index_col='ego_id', usecols=['ego_id', 'u', 'v', 'x1'])
test
# Out:
#                  u    v            x1
# ego_id
# 8               20   19  3.839089e-04
# 8              131  125  4.034464e-01
# 8               73   56  8.554643e-05
# 8                0    4  2.886418e-01
# 8               63   73  4.281692e-07
# ...            ...  ...           ...
# 1709396984676   89    0  1.167843e+00
# 1709396984676   84   87  1.179100e-06
# 1709396984676    8   18  1.175182e+00
# 1709396984676   33   20  5.511019e-01
# 1709396984676    3    1  1.422682e+00
#
# [40548780 rows x 3 columns]

# %%
train_df = []
for ego_id, ego_net_x2, ego_net_x3 in tqdm(read_ego_net('./data/train.csv'), total=61786):
    X = train.loc[ego_id].reset_index()
    
    vertex_cnt = ego_net_x2.get_n()
    
    if len(X) == 0:
        continue
    
    g = ego_net_x2.to_array()
    
    X['x2'] = g[X.u, X.v]
    
    x2_sum = g.sum(axis=1)
    X['u_x2_sum'] = x2_sum[X.u]
    X['v_x2_sum'] = x2_sum[X.v]
    
    x2_max = g.max(axis=1)
    X['u_x2_max'] = x2_max[X.u]
    X['v_x2_max'] = x2_max[X.v]
    
    sc = g.dot(g.T).flatten()
    X['SC_x2'] = sc[X.u * vertex_cnt + X.v]
    
    g = ego_net_x3.to_array()
    
    X['x3'] = g[X.u, X.v]
    
    x3_sum = g.sum(axis=1)
    X['u_x3_sum'] = x3_sum[X.u]
    X['v_x3_sum'] = x3_sum[X.v]
    
    x3_max = g.max(axis=1)
    X['u_x3_max'] = x3_max[X.u]
    X['v_x3_max'] = x3_max[X.v]
    
    sc = g.dot(g.T).flatten()
    X['SC_x3'] = sc[X.u * vertex_cnt + X.v]
    
    train_df.append(X)
# Out:
#   0%|          | 0/61786 [00:00<?, ?it/s]

# %%
train_df = pd.concat(train_df)
train_df
# Out:
#       ego_id    u    v            x1        x2   u_x2_sum    v_x2_sum  \
# 0          0  131   84  5.669200e-07  1.000000   7.000000   10.000000
# 1          0  135  164  6.246274e-02  1.000000   4.000000    5.000000
# 2          0   47   15  0.000000e+00  1.000000   3.000000    3.000000
# 3          0    5    4  4.962974e-02  1.000000  24.693148   10.000000
# 4          0  176  219  1.237935e+00  1.000000  24.057190   25.247082
# ...      ...  ...  ...           ...       ...        ...         ...
# 1637       0  253  158  1.497307e-01  1.000000   4.000000    4.000000
# 1638       0  259  244  1.827714e+00  2.609438  20.451031   15.442652
# 1639       0  209  127  6.636844e-02  1.000000  28.983776   27.579250
# 1640       0  187  241  3.756446e+00  3.833213  31.558306   21.988985
# 1641       0  168    0  1.632408e-03  1.000000  16.178055  207.593582
#
#       u_x2_max  v_x2_max      SC_x2   x3  u_x3_sum  v_x3_sum  u_x3_max  \
# 0     1.000000  1.000000   2.000000  1.0       7.0      10.0       1.0
# 1     1.000000  1.000000   2.000000  1.0       4.0       5.0       1.0
# 2     1.000000  1.000000   0.000000  2.0       6.0       3.0       2.0
# 3     1.693147  1.000000   7.693147  1.0      24.0      10.0       1.0
# 4     3.995732  6.860786  11.860786  1.0      19.0      24.0       2.0
# ...        ...       ...        ...  ...       ...       ...       ...
# 1637  1.000000  1.000000   1.000000  2.0       7.0       4.0       2.0
# 1638  6.897154  3.833213   5.944439  2.0      15.0      15.0       2.0
# 1639  5.454347  3.890372   8.609438  1.0      19.0      34.0       1.0
# 1640  6.961005  4.295837  11.289363  1.0      10.0      18.0       1.0
# 1641  4.178054  3.890372  12.178054  1.0      13.0     193.0       1.0
#
#       v_x3_max  SC_x3
# 0          1.0    2.0
# 1          1.0    2.0
# 2          1.0    0.0
# 3          1.0    7.0
# 4          2.0    9.0
# ...        ...    ...
# 1637       1.0    1.0
# 1638       2.0    7.0
# 1639       2.0   13.0
# 1640       1.0    4.0
# 1641       1.0    9.0
#
# [1642 rows x 16 columns]

# %%
test_df = []
for ego_id, ego_net_x2, ego_net_x3 in tqdm(read_ego_net('./data/test.csv'), total=20596):
    X = test.loc[ego_id].reset_index()
    
    vertex_cnt = ego_net_x2.get_n()
    
    if len(X) == 0:
        continue
    
    g = ego_net_x2.to_array()
    
    X['x2'] = g[X.u, X.v]
    
    x2_sum = g.sum(axis=1)
    X['u_x2_sum'] = x2_sum[X.u]
    X['v_x2_sum'] = x2_sum[X.v]
    
    x2_max = g.max(axis=1)
    X['u_x2_max'] = x2_max[X.u]
    X['v_x2_max'] = x2_max[X.v]
    
    sc = g.dot(g.T).flatten()
    X['SC_x2'] = sc[X.u * vertex_cnt + X.v]
    
    g = ego_net_x3.to_array()
    
    X['x3'] = g[X.u, X.v]
    
    x3_sum = g.sum(axis=1)
    X['u_x3_sum'] = x3_sum[X.u]
    X['v_x3_sum'] = x3_sum[X.v]
    
    x3_max = g.max(axis=1)
    X['u_x3_max'] = x3_max[X.u]
    X['v_x3_max'] = x3_max[X.v]
    
    sc = g.dot(g.T).flatten()
    X['SC_x3'] = sc[X.u * vertex_cnt + X.v]
    
    test_df.append(X)
# Out:
#   0%|          | 0/20596 [00:00<?, ?it/s]

# %%
test_df = pd.concat(test_df)
test_df
# Out:
#              ego_id    u    v            x1    u_x2_sum   v_x2_sum  u_x2_max  \
# 0                 8   20   19  3.839089e-04   12.000000   7.000000  1.000000
# 1                 8  131  125  4.034464e-01    6.693147   4.098612  1.693147
# 2                 8   73   56  8.554643e-05   10.000000  12.000000  1.000000
# 3                 8    0    4  2.886418e-01  130.428589   6.000000  3.564949
# 4                 8   63   73  4.281692e-07    8.000000  10.000000  1.000000
# ...             ...  ...  ...           ...         ...        ...       ...
# 1082  1709396984676   89    0  1.167843e+00    7.484907  88.665810  3.484907
# 1083  1709396984676   84   87  1.179100e-06    4.000000   4.000000  1.000000
# 1084  1709396984676    8   18  1.175182e+00   54.314777  38.044987  8.426549
# 1085  1709396984676   33   20  5.511019e-01   45.578659  43.570210  5.143135
# 1086  1709396984676    3    1  1.422682e+00    3.693147   5.000000  1.693147
#
#       v_x2_max      SC_x2  u_x3_sum  v_x3_sum  u_x3_max  v_x3_max  SC_x3
# 0     1.000000   4.000000      12.0       7.0       1.0       1.0    4.0
# 1     2.098612   4.553259       6.0       3.0       1.0       1.0    2.0
# 2     1.000000   4.000000      11.0      12.0       2.0       1.0    5.0
# 3     1.000000   0.000000     122.0       6.0       1.0       1.0    0.0
# 4     1.000000   3.000000      10.0      11.0       2.0       2.0    6.0
# ...        ...        ...       ...       ...       ...       ...    ...
# 1082  5.025352   3.000000       5.0      67.0       1.0       1.0    3.0
# 1083  1.000000   1.000000       4.0       4.0       1.0       1.0    1.0
# 1084  3.079442  34.393356      40.0      39.0       2.0       2.0   26.0
# 1085  7.453625  23.533068      46.0      26.0       2.0       2.0   18.0
# 1086  1.000000   1.693147       3.0       5.0       1.0       1.0    1.0
#
# [40548780 rows x 14 columns]

# %%
val_df = test_df[test_df.x1.notna()]
val_df
# Out:
#              ego_id    u    v            x1    u_x2_sum   v_x2_sum  u_x2_max  \
# 0                 8   20   19  3.839089e-04   12.000000   7.000000  1.000000
# 1                 8  131  125  4.034464e-01    6.693147   4.098612  1.693147
# 2                 8   73   56  8.554643e-05   10.000000  12.000000  1.000000
# 3                 8    0    4  2.886418e-01  130.428589   6.000000  3.564949
# 4                 8   63   73  4.281692e-07    8.000000  10.000000  1.000000
# ...             ...  ...  ...           ...         ...        ...       ...
# 1082  1709396984676   89    0  1.167843e+00    7.484907  88.665810  3.484907
# 1083  1709396984676   84   87  1.179100e-06    4.000000   4.000000  1.000000
# 1084  1709396984676    8   18  1.175182e+00   54.314777  38.044987  8.426549
# 1085  1709396984676   33   20  5.511019e-01   45.578659  43.570210  5.143135
# 1086  1709396984676    3    1  1.422682e+00    3.693147   5.000000  1.693147
#
#       v_x2_max      SC_x2  u_x3_sum  v_x3_sum  u_x3_max  v_x3_max  SC_x3
# 0     1.000000   4.000000      12.0       7.0       1.0       1.0    4.0
# 1     2.098612   4.553259       6.0       3.0       1.0       1.0    2.0
# 2     1.000000   4.000000      11.0      12.0       2.0       1.0    5.0
# 3     1.000000   0.000000     122.0       6.0       1.0       1.0    0.0
# 4     1.000000   3.000000      10.0      11.0       2.0       2.0    6.0
# ...        ...        ...       ...       ...       ...       ...    ...
# 1082  5.025352   3.000000       5.0      67.0       1.0       1.0    3.0
# 1083  1.000000   1.000000       4.0       4.0       1.0       1.0    1.0
# 1084  3.079442  34.393356      40.0      39.0       2.0       2.0   26.0
# 1085  7.453625  23.533068      46.0      26.0       2.0       2.0   18.0
# 1086  1.000000   1.693147       3.0       5.0       1.0       1.0    1.0
#
# [32439024 rows x 14 columns]

# %%
test_df = test_df[test_df.x1.isna()]
test_df
# Out:
#              ego_id    u    v  x1   u_x2_sum   v_x2_sum  u_x2_max  v_x2_max  \
# 9                 8  109  154 NaN   6.000000   3.000000  1.000000  1.000000
# 10                8   51   30 NaN   4.000000   4.791759  1.000000  2.791759
# 20                8   54   56 NaN  14.000000  12.000000  1.000000  1.000000
# 26                8  106    9 NaN   7.386294  18.000000  1.693147  1.000000
# 28                8  135  119 NaN   2.000000   3.791759  1.000000  2.098612
# ...             ...  ...  ...  ..        ...        ...       ...       ...
# 1063  1709396984676   58   33 NaN  17.721666  45.578659  4.367296  5.143135
# 1064  1709396984676   41    0 NaN   2.000000  88.665810  1.000000  5.025352
# 1069  1709396984676   79   33 NaN  21.385914  45.578659  4.806663  5.143135
# 1074  1709396984676   80   30 NaN  27.414795  17.890371  8.340187  2.791759
# 1079  1709396984676   33    4 NaN  45.578659   7.000000  5.143135  1.000000
#
#           SC_x2  u_x3_sum  v_x3_sum  u_x3_max  v_x3_max  SC_x3
# 9      1.000000      11.0       3.0       2.0       1.0    2.0
# 10     2.791759       4.0       6.0       1.0       2.0    2.0
# 20     6.000000      14.0      12.0       1.0       1.0    6.0
# 26     1.693147       6.0      18.0       1.0       1.0    1.0
# 28     0.000000       2.0       2.0       1.0       1.0    0.0
# ...         ...       ...       ...       ...       ...    ...
# 1063  16.420691       8.0      46.0       1.0       2.0    5.0
# 1064   1.000000       4.0      67.0       2.0       1.0    2.0
# 1069   5.386294      11.0      46.0       1.0       2.0    8.0
# 1074   1.693147      10.0      19.0       2.0       2.0    1.0
# 1079   7.025352      46.0       7.0       2.0       1.0    5.0
#
# [8109756 rows x 14 columns]

# %%
import gc
gc.collect()
# Out:
# 0

# %%
train_df['x1'].mean(), val_df['x1'].mean()
# Out:
# (0.6909816146178823, 0.6974638859342772)

# %%
from catboost import CatBoostRegressor, Pool

train_pool = Pool(
    data=train_df.drop(['ego_id', 'u', 'v', 'x1'], axis=1),
    label=train_df['x1']
)

val_pool = Pool(
    data=val_df.drop(['ego_id', 'u', 'v', 'x1'], axis=1),
    label=val_df['x1']
)
# Out:
# 2023-05-19 22:42:22,688 [69408] WARNING  py.warnings:109: [JupyterRequire] C:\Users\Konder\AppData\Roaming\Python\Python38\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [17], in <cell line: 3>()
#       1 from catboost import CatBoostRegressor, Pool
#       3 train_pool = Pool(
# ----> 4     data=train_df.drop(['ego_id', 'u', 'v', 'x1'], axis=1),
#       5     label=train_df['x1']
#       6 )
#       8 val_pool = Pool(
#       9     data=val_df.drop(['ego_id', 'u', 'v', 'x1'], axis=1),
#      10     label=val_df['x1']
#      11 )
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py:4350, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4347     new_axis = axis.take(indexer)
#    4349 bm_axis = self.ndim - axis_num - 1
# -> 4350 new_mgr = self._mgr.reindex_indexer(
#    4351     new_axis,
#    4352     indexer,
#    4353     axis=bm_axis,
#    4354     allow_dups=True,
#    4355     consolidate=consolidate,
#    4356     only_slice=only_slice,
#    4357 )
#    4358 result = self._constructor(new_mgr)
#    4359 if self.ndim == 1:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\internals\managers.py:675, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice, use_na_proxy)
#     672     return result
#     674 if consolidate:
# --> 675     self._consolidate_inplace()
#     677 # some axes don't allow reindexing with dups
#     678 if not allow_dups:
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\internals\managers.py:1685, in BlockManager._consolidate_inplace(self)
#    1683 def _consolidate_inplace(self) -> None:
#    1684     if not self.is_consolidated():
# -> 1685         self.blocks = tuple(_consolidate(self.blocks))
#    1686         self._is_consolidated = True
#    1687         self._known_consolidated = True
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\internals\managers.py:2084, in _consolidate(blocks)
#    2082 new_blocks: list[Block] = []
#    2083 for (_can_consolidate, dtype), group_blocks in grouper:
# -> 2084     merged_blocks = _merge_blocks(
#    2085         list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    2086     )
#    2087     new_blocks = extend_blocks(merged_blocks, new_blocks)
#    2088 return new_blocks
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\internals\managers.py:2118, in _merge_blocks(blocks, dtype, can_consolidate)
#    2115     new_values = bvals2[0]._concat_same_type(bvals2, axis=0)
#    2117 argsort = np.argsort(new_mgr_locs)
# -> 2118 new_values = new_values[argsort]
#    2119 new_mgr_locs = new_mgr_locs[argsort]
#    2121 bp = BlockPlacement(new_mgr_locs)
#
# MemoryError: Unable to allocate 4.56 GiB for an array with shape (10, 122280277) and data type float32

# %%
params = {
    'task_type': 'CPU',
    'loss_function': 'RMSE',
}

# %%
model_cb = CatBoostRegressor(**params, random_seed=56)
model_cb.fit(train_pool, eval_set=val_pool, plot=True, verbose=False, use_best_model=True)

# %%
np.max(model_cb.evals_result_['validation']['RMSE'])
